# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import torch
from torch import nn
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Teaching a quadruped to walk
#
# Time to try out the learning algorithms that you just implemented on a more difficult problem. The WalkerEnv implements a quadruped robot kind-of thing, see for yourself. The goal is to move in the $x$ direction as fast and as far as possible.
#
# Your goal is to implement a class `WalkerPolicy` with function `determine_actions()` just like the StochasticPolicy we used earlier to control the pendulum. Below is a template of this class, but feel free to alter it however you want. The only important thing is the `determine_actions()` function!
#
# After you implement it, copy `WalkerPolicy` into a separate file `WalkerPolicy.py` that you will upload to BRUTE together with the (optional) learned weights in a zip file. How the policy is implemented is up to you! You are constrained to only the libraries we used so far though, such as torch, numpy etc..
#
# You will get some free points just for uploading a working policy (irrelevant of the performance). Further 2 points will be awarded for successfully traversing a small distance in the x direction.

# %% [markdown]
# # Hints
#
# There is no single easy way of doing this, but here are some suggestions on what you could try to improve your policy:
#
# 1. This problem is much more difficult, than balancing a pendulum. It is a good idea to use a bit larger network than for the pendulum policy.
#
# 2. You can also try to use a different optimizer, such as Adam and play with the hyperparameters.
#
# 3. Using a neural network to compute the normal distribution scale $\sigma$ can lead to too much randomness in the actions (i.e. exploration). You can use a fixed $\sigma$ instead, or replace it with a learnable `torch.Parameter` initialized to some small constant. Make sure, you run it through an exponential, or softplus function to ensure $\sigma$ is positive.
#
# 4. The exploration can also be reduced by penalizing the variance of the action distribution in an additional loss term.
#
# 5. If you see some undesirable behaviour, you can tweak the reward function to penalize it. Even though the $x$ distance is all we care about, adding extra terms to the reward can help guide the learning process (This is known as reward shaping). Simply define a reward function mapping the state $s_{t+1}$ and action $a_t$ to a scalar reward $r_t$ and put it in the config dictionary under the key `'reward_fcn'`. See the `WalkerEnv` class for the implementation of the default reward.
#
# 6. Using the normal distribution on a bounded action space can lead to certain problems caused by action clipping. This can be mitigated by using a different distribution, such as the Beta distribution. See the `torch.distributions.beta` module for more information. (Note that Beta distribution is defined on the interval [0,1] and works better with parameters $\alpha,\beta \geq 1$.)

# %%
# If you cannot run with the visualization, you can set this to False
VISUALIZE = True

# %%
from environment.WalkerEnv import WalkerEnv
from WalkerPolicy import WalkerPolicy

# %%
def walker_reward(state, action):
    """reward function for the walker environment, state is [29] vector, action is [8] vector"""
    pos = state[:15]  # first 15 elements of state vector are generalized coordinates [xyz, quat, joint_angles]
    vel = state[15:]  # last 14 elements of state vector are generalized velocities [xyz_vel, omega, joint_velocities]
    return vel[0]  # return the x velocity as the reward by default

# %%
# This is the configuration for the Walker environment
# N is the number of robots controlled in parallel
# vis is a boolean flag to enable visualization
# !! IMPORTANT track is an integer index to enable camera tracking of a particular robot (indexed by the value of the argument), this is useful when evaluating the performance of the policy after training
# reward_fcn is the reward function that the environment will use to calculate the reward
config = {'N': 1, 'vis': VISUALIZE, "track": 0, "reward_fcn": walker_reward}
env = WalkerEnv(config)
# Out:
# Environment ready
# c:\Users\bogda\Deep Reinforcement Learning\hw5-rl-main\rl-homework-venv\lib\site-packages\glfw\__init__.py:917: GLFWError: (65537) b'The GLFW library is not initialized'
#   warnings.warn(message, GLFWError)

# %%
# T = 1000
# obs = env.vector_reset()  # Observation vector is of shape (N, 29)
# print(f"Observation shape is {obs.shape}")
# x = obs[0, 0]
# for i in range(1000):
#     a = np.random.randn(1, 8) * 4 - 2  # Random actions with standard deviation of 2 and mean of 0
#     obs, reward = env.vector_step(a)
#     x = max(x, obs[0, 0])
# env.close()
# print(f"After {T} steps, the maximum x value reached was {x}")




# env = WalkerEnv(config)

# # Initialize policy and optimizer
# policy = WalkerPolicy(state_dim=29, action_dim=8)
# optimizer = optim.Adam(policy.parameters(), lr=3e-4)

# # Training hyperparameters
# num_episodes = 1000
# max_steps_per_episode = 500
# gamma = 0.99

# # Training loop
# for episode in range(num_episodes):
#     states, actions, rewards, log_probs = [], [], [], []
#     obs = env.vector_reset()  # Reset the environment

#     for t in range(max_steps_per_episode):
#         # Convert observation to tensor
#         obs_torch = torch.tensor(obs, dtype=torch.float32)

#         # Sample actions and log-probabilities
#         action, log_prob = policy.sample_actions_and_log_prob(obs_torch)

#         # Step the environment
#         obs_next, reward = env.vector_step(action.detach().numpy())

#         # Store experience
#         states.append(obs_torch)
#         actions.append(action)
#         rewards.append(torch.tensor(reward, dtype=torch.float32))
#         log_probs.append(log_prob)

#         obs = obs_next

#     # Compute discounted returns
#     rewards = torch.stack(rewards)  # Shape (T, 1)
#     discounted_returns = torch.zeros_like(rewards)
#     running_sum = 0.0

#     for t in reversed(range(len(rewards))):
#         running_sum = rewards[t] + gamma * running_sum
#         discounted_returns[t] = running_sum

#     # Prepare data for policy gradient computation
#     states = torch.stack(states)
#     actions = torch.stack(actions)
#     log_probs = torch.cat(log_probs)
#     returns = discounted_returns

#     # Compute loss
#     policy_loss = - (log_probs * returns).mean()

#     # Update policy
#     optimizer.zero_grad()
#     policy_loss.backward()
#     optimizer.step()

#     # Logging
#     total_return = returns.sum().item()
#     print(f"Episode {episode + 1}, Total Return: {total_return:.2f}")

# policy.save_weights("walker_weights.pt")

# env.close()
# print("Training complete.")

env = WalkerEnv(config)

# Initialize policy and load pretrained weights
policy = WalkerPolicy(state_dim=29, action_dim=8, load_weights=True)
policy.load_weights("walker_weights.pt")  # Load the pretrained weights

# Validation hyperparameters
num_validation_episodes = 10
max_steps_per_episode = 500

# Validation loop
for episode in range(num_validation_episodes):
    obs = env.vector_reset()  # Reset the environment
    total_return = 0.0

    for t in range(max_steps_per_episode):
        # Convert observation to tensor
        obs_torch = torch.tensor(obs, dtype=torch.float32)

        # Use the trained policy to determine actions
        action = policy.determine_actions(obs_torch)

        # Step the environment
        obs_next, reward = env.vector_step(action.detach().numpy())

        # Accumulate reward
        total_return += reward[0]
        obs = obs_next

    print(f"Validation Episode {episode + 1}, Total Return: {total_return:.2f}")

env.close()
print("Validation complete.")
# Out:
# Environment ready
# Episode 1, Total Return: 2939.12
# Episode 2, Total Return: -431.21
# Episode 3, Total Return: -1619.18
# Episode 4, Total Return: -2756.68
# Episode 5, Total Return: -1479.39
# Episode 6, Total Return: 2897.80
# Episode 7, Total Return: 4312.67
# Episode 8, Total Return: -106.67
# Episode 9, Total Return: -1266.22
# Episode 10, Total Return: -26.32
# Episode 11, Total Return: 3142.88
# Episode 12, Total Return: 1223.46
# Episode 13, Total Return: 2351.47
# Episode 14, Total Return: 3576.44
# Episode 15, Total Return: 2133.28
# Episode 16, Total Return: -85.05
# Episode 17, Total Return: -951.43
# Episode 18, Total Return: 2397.81
# Episode 19, Total Return: -2732.25
# Episode 20, Total Return: -1420.50
# Episode 21, Total Return: 484.35
# Episode 22, Total Return: -1708.03
# Episode 23, Total Return: -2056.43
# Episode 24, Total Return: 2566.36
# Episode 25, Total Return: 3249.27
# Episode 26, Total Return: 2135.59
# Episode 27, Total Return: 603.66
# Episode 28, Total Return: 1141.60
# Episode 29, Total Return: -1593.38
# Episode 30, Total Return: 88.88
# Episode 31, Total Return: 800.17
# Episode 32, Total Return: 2015.46
# Episode 33, Total Return: -814.43
# Episode 34, Total Return: 1208.56
# Episode 35, Total Return: -2912.46
# Episode 36, Total Return: 1053.42
# Episode 37, Total Return: 2940.43
# Episode 38, Total Return: -3347.70
# Episode 39, Total Return: -2402.17
# Episode 40, Total Return: -3739.07
# Episode 41, Total Return: -2567.33
# Episode 42, Total Return: 1394.81
# Episode 43, Total Return: 534.14
# Episode 44, Total Return: 234.74
# Episode 45, Total Return: 1609.20
# Episode 46, Total Return: -2750.52
# Episode 47, Total Return: 1832.91
# Episode 48, Total Return: 264.60
# Episode 49, Total Return: 289.05
# Episode 50, Total Return: 334.53
# Episode 51, Total Return: 428.12
# Episode 52, Total Return: 518.48
# Episode 53, Total Return: -78.05
# Episode 54, Total Return: -3109.15
# Episode 55, Total Return: -225.38
# Episode 56, Total Return: -387.42
# Episode 57, Total Return: 2556.20
# Episode 58, Total Return: -890.84
# Episode 59, Total Return: 3171.56
# Episode 60, Total Return: 3905.94
# Episode 61, Total Return: -484.50
# Episode 62, Total Return: -2352.59
# Episode 63, Total Return: 2281.13
# Episode 64, Total Return: -968.62
# Episode 65, Total Return: 1294.92
# Episode 66, Total Return: 1586.03
# Episode 67, Total Return: -3132.61
# Episode 68, Total Return: 2235.72
# Episode 69, Total Return: -3930.86
# Episode 70, Total Return: 334.49
# Episode 71, Total Return: 1689.71
# Episode 72, Total Return: 1910.10
# Episode 73, Total Return: 918.37
# Episode 74, Total Return: -3341.68
# Episode 75, Total Return: -1233.43
# Episode 76, Total Return: 418.28
# Episode 77, Total Return: 3194.64
# Episode 78, Total Return: -2254.65
# Episode 79, Total Return: -2449.49
# Episode 80, Total Return: -2448.25
# Episode 81, Total Return: 206.72
# Episode 82, Total Return: 1521.03
# Episode 83, Total Return: 973.57
# Episode 84, Total Return: -643.49
# Episode 85, Total Return: -1920.65
# Episode 86, Total Return: 121.68
# Episode 87, Total Return: -935.07
# Episode 88, Total Return: -3777.51
# Episode 89, Total Return: -1757.80
# Episode 90, Total Return: -2027.17
# Episode 91, Total Return: -2278.51
# Episode 92, Total Return: -327.37
# Episode 93, Total Return: -2723.23
# Episode 94, Total Return: -53.16
# Episode 95, Total Return: -6121.87
# Episode 96, Total Return: 2534.87
# Episode 97, Total Return: -2396.03
# Episode 98, Total Return: 16.29
# Episode 99, Total Return: -190.06
# Episode 100, Total Return: -4219.11
# Episode 101, Total Return: -375.80
# Episode 102, Total Return: 2753.50
# Episode 103, Total Return: -304.15
# Episode 104, Total Return: 511.57
# Episode 105, Total Return: 1071.63
# Episode 106, Total Return: -1995.54
# Episode 107, Total Return: -45.51
# Episode 108, Total Return: 1314.93
# Episode 109, Total Return: -98.26
# Episode 110, Total Return: -926.42
# Episode 111, Total Return: 2096.02
# Episode 112, Total Return: -3919.37
# Episode 113, Total Return: 1464.27
# Episode 114, Total Return: -1136.75
# Episode 115, Total Return: 790.88
# Episode 116, Total Return: -2250.76
# Episode 117, Total Return: 1312.45
# Episode 118, Total Return: 652.15
# Episode 119, Total Return: 2266.72
# Episode 120, Total Return: 884.34
# Episode 121, Total Return: -45.61
# Episode 122, Total Return: 17.54
# Episode 123, Total Return: -1151.39
# Episode 124, Total Return: -1439.04
# Episode 125, Total Return: -1051.28
# Episode 126, Total Return: 118.74
# Episode 127, Total Return: 530.09
# Episode 128, Total Return: 2093.21
# Episode 129, Total Return: 1528.40
# Episode 130, Total Return: 1510.14
# Episode 131, Total Return: -536.41
# Episode 132, Total Return: 1837.35
# Episode 133, Total Return: -1027.58
# Episode 134, Total Return: 2367.28
# Episode 135, Total Return: -774.11
# Episode 136, Total Return: 27.71
# Episode 137, Total Return: 1374.80
# Episode 138, Total Return: -2565.14
# Episode 139, Total Return: -2053.91
# Episode 140, Total Return: -770.41
# Episode 141, Total Return: 1406.70
# Episode 142, Total Return: -1756.25
# Episode 143, Total Return: 3.68
# Episode 144, Total Return: -738.16
# Episode 145, Total Return: -1810.40
# Episode 146, Total Return: -1552.14
# Episode 147, Total Return: -559.52
# Episode 148, Total Return: 206.94
# Episode 149, Total Return: 363.29
# Episode 150, Total Return: -365.84
# Episode 151, Total Return: 854.63
# Episode 152, Total Return: -1335.21
# Episode 153, Total Return: -1633.31
# Episode 154, Total Return: -4073.11
# Episode 155, Total Return: -309.45
# Episode 156, Total Return: -666.37
# Episode 157, Total Return: -855.43
# Episode 158, Total Return: -2073.82
# Episode 159, Total Return: -1930.91
# Episode 160, Total Return: -2429.59
# Episode 161, Total Return: -2724.95
# Episode 162, Total Return: 416.56
# Episode 163, Total Return: -2068.75
# Episode 164, Total Return: -1408.44
# Episode 165, Total Return: -1400.56
# Episode 166, Total Return: -724.12
# Episode 167, Total Return: 762.84
# Episode 168, Total Return: -83.05
# Episode 169, Total Return: -1283.07
# Episode 170, Total Return: -1781.60
# Episode 171, Total Return: -793.11
# Episode 172, Total Return: -2566.26
# Episode 173, Total Return: -700.45
# Episode 174, Total Return: 967.36
# Episode 175, Total Return: 1839.10
# Episode 176, Total Return: 487.24
# Episode 177, Total Return: 543.51
# Episode 178, Total Return: -1840.94
# Episode 179, Total Return: -1944.11
# Episode 180, Total Return: -694.92
# Episode 181, Total Return: -1342.83
# Episode 182, Total Return: 1373.17
# Episode 183, Total Return: -662.08
# Episode 184, Total Return: 2433.56
# Episode 185, Total Return: -2251.05
# Episode 186, Total Return: -499.75
# Episode 187, Total Return: 846.47
# Episode 188, Total Return: 1269.07
# Episode 189, Total Return: 5472.64
# Episode 190, Total Return: 448.24
# Episode 191, Total Return: -2599.81
# Episode 192, Total Return: -3876.11
# Episode 193, Total Return: 4806.71
# Episode 194, Total Return: -210.55
# Episode 195, Total Return: -1885.48
# Episode 196, Total Return: -495.86
# Episode 197, Total Return: -1435.71
# Episode 198, Total Return: 2159.85
# Episode 199, Total Return: 1945.36
# Episode 200, Total Return: 2895.63
# Episode 201, Total Return: -2193.88
# Episode 202, Total Return: 2173.96
# Episode 203, Total Return: -1462.78
# Episode 204, Total Return: 2339.34
# Episode 205, Total Return: 3386.54
# Episode 206, Total Return: 917.78
# Episode 207, Total Return: -20.61
# Episode 208, Total Return: 148.20
# Episode 209, Total Return: -1287.39
# Episode 210, Total Return: 3215.46
# Episode 211, Total Return: -1351.41
# Episode 212, Total Return: -659.12
# Episode 213, Total Return: -1115.67
# Episode 214, Total Return: -357.78
# Episode 215, Total Return: 1530.67
# Episode 216, Total Return: -347.40
# Episode 217, Total Return: 1296.80
# Episode 218, Total Return: -1253.72
# Episode 219, Total Return: -1047.04
# Episode 220, Total Return: 1128.87
# Episode 221, Total Return: 4974.68
# Episode 222, Total Return: 826.02
# Episode 223, Total Return: 522.67
# Episode 224, Total Return: 2190.03
# Episode 225, Total Return: -1570.25
# Episode 226, Total Return: -495.26
# Episode 227, Total Return: -1414.48
# Episode 228, Total Return: -246.42
# Episode 229, Total Return: -1629.72
# Episode 230, Total Return: 864.90
# Episode 231, Total Return: 1953.09
# Episode 232, Total Return: -2281.98
# Episode 233, Total Return: -461.59
# Episode 234, Total Return: 1674.44
# Episode 235, Total Return: 2048.08
# Episode 236, Total Return: 5323.42
# Episode 237, Total Return: -151.69
# Episode 238, Total Return: 7.11
# Episode 239, Total Return: -2947.98
# Episode 240, Total Return: 3767.05
# Episode 241, Total Return: 1466.58
# Episode 242, Total Return: 834.27
# Episode 243, Total Return: 4401.02
# Episode 244, Total Return: -2279.89
# Episode 245, Total Return: -595.92
# Episode 246, Total Return: 923.50
# Episode 247, Total Return: 715.01
# Episode 248, Total Return: 1496.82
# Episode 249, Total Return: 4917.40
# Episode 250, Total Return: 295.62
# Episode 251, Total Return: 1338.85
# Episode 252, Total Return: -495.17
# Episode 253, Total Return: 3805.19
# Episode 254, Total Return: 3860.77
# Episode 255, Total Return: 885.89
# Episode 256, Total Return: -1111.47
# Episode 257, Total Return: 437.15
# Episode 258, Total Return: 3916.12
# Episode 259, Total Return: 3573.68
# Episode 260, Total Return: 1073.31
# Episode 261, Total Return: -274.62
# Episode 262, Total Return: 1378.99
# Episode 263, Total Return: 3074.34
# Episode 264, Total Return: 882.54
# Episode 265, Total Return: -674.34
# Episode 266, Total Return: 2074.94
# Episode 267, Total Return: 2782.60
# Episode 268, Total Return: 1539.13
# Episode 269, Total Return: 2604.86
# Episode 270, Total Return: -1803.08
# Episode 271, Total Return: 3817.92
# Episode 272, Total Return: 1847.29
# Episode 273, Total Return: 5637.16
# Episode 274, Total Return: 1011.68
# Episode 275, Total Return: 1209.38
# Episode 276, Total Return: 39.13
# Episode 277, Total Return: 3753.20
# Episode 278, Total Return: 1092.19
# Episode 279, Total Return: 1315.45
# Episode 280, Total Return: -450.97
# Episode 281, Total Return: 3764.75
# Episode 282, Total Return: 3402.68
# Episode 283, Total Return: 5011.83
# Episode 284, Total Return: 1469.28
# Episode 285, Total Return: -1064.61
# Episode 286, Total Return: 4499.68
# Episode 287, Total Return: 2073.69
# Episode 288, Total Return: 3074.48
# Episode 289, Total Return: 1782.32
# Episode 290, Total Return: -2313.48
# Episode 291, Total Return: 526.34
# Episode 292, Total Return: 438.23
# Episode 293, Total Return: 496.16
# Episode 294, Total Return: 2494.19
# Episode 295, Total Return: 1899.06
# Episode 296, Total Return: 3289.72
# Episode 297, Total Return: 2692.02
# Episode 298, Total Return: -1027.20
# Episode 299, Total Return: 455.69
# Episode 300, Total Return: 584.03
# Episode 301, Total Return: -2018.51
# Episode 302, Total Return: 1390.51
# Episode 303, Total Return: 3051.66
# Episode 304, Total Return: 434.14
# Episode 305, Total Return: 2757.08
# Episode 306, Total Return: -948.10
# Episode 307, Total Return: 1372.11
# Episode 308, Total Return: 3092.07
# Episode 309, Total Return: 3522.48
# Episode 310, Total Return: 2360.60
# Episode 311, Total Return: 2953.27
# Episode 312, Total Return: 3846.15
# Episode 313, Total Return: 912.07
# Episode 314, Total Return: 3342.20
# Episode 315, Total Return: 1000.07
# Episode 316, Total Return: 2841.81
# Episode 317, Total Return: 1806.68
# Episode 318, Total Return: 3134.43
# Episode 319, Total Return: 210.35
# Episode 320, Total Return: 1437.14
# Episode 321, Total Return: 865.46
# Episode 322, Total Return: 2640.69
# Episode 323, Total Return: -13.46
# Episode 324, Total Return: 2935.42
# Episode 325, Total Return: 1018.75
# Episode 326, Total Return: 962.34
# Episode 327, Total Return: -535.12
# Episode 328, Total Return: -1292.50
# Episode 329, Total Return: 4287.73
# Episode 330, Total Return: 2272.30
# Episode 331, Total Return: -2350.57
# Episode 332, Total Return: -13.41
# Episode 333, Total Return: 1551.78
# Episode 334, Total Return: -543.10
# Episode 335, Total Return: 2160.32
# Episode 336, Total Return: -526.13
# Episode 337, Total Return: -545.85
# Episode 338, Total Return: -633.71
# Episode 339, Total Return: 3214.98
# Episode 340, Total Return: -662.65
# Episode 341, Total Return: 630.84
# Episode 342, Total Return: 824.47
# Episode 343, Total Return: 140.39
# Episode 344, Total Return: 3678.51
# Episode 345, Total Return: 1117.77
# Episode 346, Total Return: 944.11
# Episode 347, Total Return: 1438.67
# Episode 348, Total Return: 1333.45
# Episode 349, Total Return: 233.11
# Episode 350, Total Return: 988.81
# Episode 351, Total Return: 2795.22
# Episode 352, Total Return: -496.75
# Episode 353, Total Return: 5519.27
# Episode 354, Total Return: -1061.58
# Episode 355, Total Return: -801.32
# Episode 356, Total Return: 2455.22
# Episode 357, Total Return: 4181.31
# Episode 358, Total Return: 2889.04
# Episode 359, Total Return: 1517.17
# Episode 360, Total Return: -1749.26
# Episode 361, Total Return: 3466.08
# Episode 362, Total Return: 4041.10
# Episode 363, Total Return: 727.52
# Episode 364, Total Return: 2854.83
# Episode 365, Total Return: 4398.55
# Episode 366, Total Return: 3679.54
# Episode 367, Total Return: -1301.99
# Episode 368, Total Return: 3371.58
# Episode 369, Total Return: -3089.91
# Episode 370, Total Return: 6489.45
# Episode 371, Total Return: 3719.56
# Episode 372, Total Return: 3055.66
# Episode 373, Total Return: 4802.80
# Episode 374, Total Return: 4652.05
# Episode 375, Total Return: 217.37
# Episode 376, Total Return: 3352.32
# Episode 377, Total Return: -327.43
# Episode 378, Total Return: 1947.77
# Episode 379, Total Return: 2377.91
# Episode 380, Total Return: 3137.91
# Episode 381, Total Return: 5405.53
# Episode 382, Total Return: 2090.25
# Episode 383, Total Return: 1215.33
# Episode 384, Total Return: 4995.07
# Episode 385, Total Return: 2417.07
# Episode 386, Total Return: 2384.71
# Episode 387, Total Return: 3268.40
# Episode 388, Total Return: 3579.83
# Episode 389, Total Return: 2173.32
# Episode 390, Total Return: 6504.42
# Episode 391, Total Return: 1746.31
# Episode 392, Total Return: 2440.06
# Episode 393, Total Return: 4207.21
# Episode 394, Total Return: 4406.01
# Episode 395, Total Return: 3346.92
# Episode 396, Total Return: 5419.08
# Episode 397, Total Return: 3040.39
# Episode 398, Total Return: 1934.80
# Episode 399, Total Return: 266.64
# Episode 400, Total Return: 3173.71
# Episode 401, Total Return: 4085.29
# Episode 402, Total Return: 4519.87
# Episode 403, Total Return: 693.05
# Episode 404, Total Return: 1934.87
# Episode 405, Total Return: 5877.58
# Episode 406, Total Return: 1556.04
# Episode 407, Total Return: 4072.19
# Episode 408, Total Return: 2328.00
# Episode 409, Total Return: 1297.80
# Episode 410, Total Return: 4097.71
# Episode 411, Total Return: 7922.29
# Episode 412, Total Return: 7654.28
# Episode 413, Total Return: 1838.92
# Episode 414, Total Return: 3915.71
# Episode 415, Total Return: 6477.29
# Episode 416, Total Return: 3951.03
# Episode 417, Total Return: 4871.50
# Episode 418, Total Return: 3564.11
# Episode 419, Total Return: 658.10
# Episode 420, Total Return: 5162.54
# Episode 421, Total Return: 4239.94
# Episode 422, Total Return: 4747.18
# Episode 423, Total Return: 5307.84
# Episode 424, Total Return: 7367.14
# Episode 425, Total Return: 1083.63
# Episode 426, Total Return: 3961.33
# Episode 427, Total Return: 6626.86
# Episode 428, Total Return: 1628.72
# Episode 429, Total Return: 3396.56
# Episode 430, Total Return: 3602.02
# Episode 431, Total Return: 5308.66
# Episode 432, Total Return: 7873.49
# Episode 433, Total Return: 7264.08
# Episode 434, Total Return: 8710.06
# Episode 435, Total Return: 9808.62
# Episode 436, Total Return: 6217.51
# Episode 437, Total Return: 7223.09
# Episode 438, Total Return: 3009.77
# Episode 439, Total Return: 6610.52
# Episode 440, Total Return: 1358.96
# Episode 441, Total Return: 8357.72
# Episode 442, Total Return: 802.93
# Episode 443, Total Return: 8335.87
# Episode 444, Total Return: 8195.25
# Episode 445, Total Return: 9030.46
# Episode 446, Total Return: 9603.12
# Episode 447, Total Return: 8208.62
# Episode 448, Total Return: 7606.99
# Episode 449, Total Return: 6399.20
# Episode 450, Total Return: -992.88
# Episode 451, Total Return: 10473.46
# Episode 452, Total Return: 6506.96
# Episode 453, Total Return: 3238.54
# Episode 454, Total Return: 460.20
# Episode 455, Total Return: 7331.28
# Episode 456, Total Return: 1434.03
# Episode 457, Total Return: 12895.97
# Episode 458, Total Return: 2859.84
# Episode 459, Total Return: 11279.83
# Episode 460, Total Return: 13006.86
# Episode 461, Total Return: 8061.78
# Episode 462, Total Return: 13405.01
# Episode 463, Total Return: -5841.16
# Episode 464, Total Return: 6305.82
# Episode 465, Total Return: 813.01
# Episode 466, Total Return: -132.41
# Episode 467, Total Return: 209.21
# Episode 468, Total Return: 253.71
# Episode 469, Total Return: 2270.24
# Episode 470, Total Return: -1142.06
# Episode 471, Total Return: 52.00
# Episode 472, Total Return: 811.55
# Episode 473, Total Return: -388.90
# Episode 474, Total Return: 2080.19
# Episode 475, Total Return: -4577.65
# Episode 476, Total Return: -3412.43
# Episode 477, Total Return: 2334.97
# Episode 478, Total Return: 654.03
# Episode 479, Total Return: 2884.05
# Episode 480, Total Return: -340.69
# Episode 481, Total Return: -114.86
# Episode 482, Total Return: 3855.73
# Episode 483, Total Return: 2176.19
# Episode 484, Total Return: 704.82
# Episode 485, Total Return: 1371.39
# Episode 486, Total Return: 2706.20
# Episode 487, Total Return: -6345.26
# Episode 488, Total Return: 1545.89
# Episode 489, Total Return: 2118.50
# Episode 490, Total Return: 3675.22
# Episode 491, Total Return: 11098.36
# Episode 492, Total Return: -315.76
# Episode 493, Total Return: 5028.24
# Episode 494, Total Return: 2657.77
# Episode 495, Total Return: 2508.43
# Episode 496, Total Return: 3747.37
# Episode 497, Total Return: 745.18
# Episode 498, Total Return: 1903.20
# Episode 499, Total Return: 1763.58
# Episode 500, Total Return: -4911.17
# Episode 501, Total Return: 7409.64
# Episode 502, Total Return: 3555.31
# Episode 503, Total Return: 5678.58
# Episode 504, Total Return: 10659.45
# Episode 505, Total Return: 5943.40
# Episode 506, Total Return: 2676.33
# Episode 507, Total Return: 2583.19
# Episode 508, Total Return: 10627.23
# Episode 509, Total Return: 6923.80
# Episode 510, Total Return: 2057.44
# Episode 511, Total Return: 9017.90
# Episode 512, Total Return: 1732.45
# Episode 513, Total Return: 561.03
# Episode 514, Total Return: 8669.39
# Episode 515, Total Return: 6664.40
# Episode 516, Total Return: 12406.77
# Episode 517, Total Return: 1516.50
# Episode 518, Total Return: -4295.73
# Episode 519, Total Return: 551.11
# Episode 520, Total Return: 11026.67
# Episode 521, Total Return: 4834.82
# Episode 522, Total Return: 6407.71
# Episode 523, Total Return: -707.36
# Episode 524, Total Return: -787.68
# Episode 525, Total Return: 6212.93
# Episode 526, Total Return: 414.21
# Episode 527, Total Return: 7841.30
# Episode 528, Total Return: -1214.15
# Episode 529, Total Return: 5232.12
# Episode 530, Total Return: 3171.14
# Episode 531, Total Return: 4232.70
# Episode 532, Total Return: 1050.07
# Episode 533, Total Return: 10000.50
# Episode 534, Total Return: 6740.27
# Episode 535, Total Return: -4082.83
# Episode 536, Total Return: 4005.51
# Episode 537, Total Return: -1322.06
# Episode 538, Total Return: 4363.36
# Episode 539, Total Return: 1547.90
# Episode 540, Total Return: 3973.66
# Episode 541, Total Return: 2118.50
# Episode 542, Total Return: 94.73
# Episode 543, Total Return: 2214.21
# Episode 544, Total Return: 317.33
# Episode 545, Total Return: 8835.11
# Episode 546, Total Return: -403.90
# Episode 547, Total Return: 954.95
# Episode 548, Total Return: 181.16
# Episode 549, Total Return: 4531.85
# Episode 550, Total Return: 5882.41
# Episode 551, Total Return: -1870.89
# Episode 552, Total Return: 2678.92
# Episode 553, Total Return: 6367.67
# Episode 554, Total Return: -7394.53
# Episode 555, Total Return: -3106.68
# Episode 556, Total Return: 3018.31
# Episode 557, Total Return: -3271.48
# Episode 558, Total Return: 5477.91
# Episode 559, Total Return: 6181.81
# Episode 560, Total Return: 879.37
# Episode 561, Total Return: 8369.71
# Episode 562, Total Return: -4723.37
# Episode 563, Total Return: 2402.69
# Episode 564, Total Return: 9002.89
# Episode 565, Total Return: 2476.03
# Episode 566, Total Return: 3653.98
# Episode 567, Total Return: 2489.92
# Episode 568, Total Return: -1073.77
# Episode 569, Total Return: 1859.40
# Episode 570, Total Return: 1254.12
# Episode 571, Total Return: -192.27
# Episode 572, Total Return: 1445.45
# Episode 573, Total Return: 6378.25
# Episode 574, Total Return: 10286.65
# Episode 575, Total Return: 5268.31
# Episode 576, Total Return: 5550.05
# Episode 577, Total Return: -524.26
# Episode 578, Total Return: -4334.96
# Episode 579, Total Return: 6458.73
# Episode 580, Total Return: 4724.56
# Episode 581, Total Return: 8164.53
# Episode 582, Total Return: -1697.22
# Episode 583, Total Return: 8769.74
# Episode 584, Total Return: 8404.10
# Episode 585, Total Return: 6327.23
# Episode 586, Total Return: 783.31
# Episode 587, Total Return: 4025.56
# Episode 588, Total Return: 6465.31
# Episode 589, Total Return: 6146.77
# Episode 590, Total Return: 1947.12
# Episode 591, Total Return: 523.74
# Episode 592, Total Return: 4221.27
# Episode 593, Total Return: 7588.42
# Episode 594, Total Return: 8204.73
# Episode 595, Total Return: 6093.15
# Episode 596, Total Return: -373.34
# Episode 597, Total Return: -4087.78
# Episode 598, Total Return: 3183.39
# Episode 599, Total Return: 5474.86
# Episode 600, Total Return: -4481.41
# Episode 601, Total Return: 11144.61
# Episode 602, Total Return: 4837.90
# Episode 603, Total Return: -7431.59
# Episode 604, Total Return: -314.28
# Episode 605, Total Return: -4752.30
# Episode 606, Total Return: 2328.95
# Episode 607, Total Return: -5375.91
# Episode 608, Total Return: 8213.54
# Episode 609, Total Return: 4966.34
# Episode 610, Total Return: 8591.89
# Episode 611, Total Return: 7406.63
# Episode 612, Total Return: 9993.32
# Episode 613, Total Return: 2298.79
# Episode 614, Total Return: 2010.83
# Episode 615, Total Return: 760.76
# Episode 616, Total Return: 9399.97
# Episode 617, Total Return: -6299.84
# Episode 618, Total Return: -2076.33
# Episode 619, Total Return: 6065.40
# Episode 620, Total Return: 2496.18
# Episode 621, Total Return: 8234.84
# Episode 622, Total Return: 8994.84
# Episode 623, Total Return: 3213.11
# Episode 624, Total Return: 446.57
# Episode 625, Total Return: 13586.11
# Episode 626, Total Return: 17452.84
# Episode 627, Total Return: 542.34
# Episode 628, Total Return: 4799.48
# Episode 629, Total Return: -2004.93
# Episode 630, Total Return: 7829.72
# Episode 631, Total Return: 6556.64
# Episode 632, Total Return: 11599.29
# Episode 633, Total Return: -1081.30
# Episode 634, Total Return: 8403.80
# Episode 635, Total Return: 11303.16
# Episode 636, Total Return: 1014.27
# Episode 637, Total Return: -7237.63
# Episode 638, Total Return: 4314.97
# Episode 639, Total Return: 8229.84
# Episode 640, Total Return: 16048.82
# Episode 641, Total Return: 8401.67
# Episode 642, Total Return: 2683.29
# Episode 643, Total Return: 2158.81
# Episode 644, Total Return: -16459.13
# Episode 645, Total Return: 10733.80
# Episode 646, Total Return: 8832.91
# Episode 647, Total Return: 4261.85
# Episode 648, Total Return: 12895.81
# Episode 649, Total Return: 8137.03
# Episode 650, Total Return: 7234.72
# Episode 651, Total Return: -5.17
# Episode 652, Total Return: 13315.55
# Episode 653, Total Return: 4310.94
# Episode 654, Total Return: -5344.78
# Episode 655, Total Return: 4897.75
# Episode 656, Total Return: 7743.64
# Episode 657, Total Return: 6404.20
# Episode 658, Total Return: 8527.70
# Episode 659, Total Return: 2445.25
# Episode 660, Total Return: 10347.70
# Episode 661, Total Return: 1165.23
# Episode 662, Total Return: -6091.53
# Episode 663, Total Return: 10283.66
# Episode 664, Total Return: -81.74
# Episode 665, Total Return: 7717.80
# Episode 666, Total Return: 4259.91
# Episode 667, Total Return: 5853.48
# Episode 668, Total Return: 3643.40
# Episode 669, Total Return: -3293.23
# Episode 670, Total Return: 1790.53
# Episode 671, Total Return: 3952.46
# Episode 672, Total Return: -4390.39
# Episode 673, Total Return: 11648.68
# Episode 674, Total Return: -2685.19
# Episode 675, Total Return: 10183.59
# Episode 676, Total Return: 2848.80
# Episode 677, Total Return: -996.61
# Episode 678, Total Return: 1539.76
# Episode 679, Total Return: 1121.52
# Episode 680, Total Return: 252.37
# Episode 681, Total Return: 4900.96
# Episode 682, Total Return: 12494.26
# Episode 683, Total Return: -6570.23
# Episode 684, Total Return: 2220.27
# Episode 685, Total Return: 2604.70
# Episode 686, Total Return: 8465.25
# Episode 687, Total Return: 9583.63
# Episode 688, Total Return: 11860.98
# Episode 689, Total Return: 704.66
# Episode 690, Total Return: 4951.92
# Episode 691, Total Return: 7776.63
# Episode 692, Total Return: 345.90
# Episode 693, Total Return: 8970.24
# Episode 694, Total Return: 4900.38
# Episode 695, Total Return: 4923.23
# Episode 696, Total Return: 821.22
# Episode 697, Total Return: -2157.53
# Episode 698, Total Return: 10855.08
# Episode 699, Total Return: -5188.92
# Episode 700, Total Return: -522.75
# Episode 701, Total Return: 2200.29
# Episode 702, Total Return: 1250.21
# Episode 703, Total Return: 9049.68
# Episode 704, Total Return: 514.50
# Episode 705, Total Return: 3739.51
# Episode 706, Total Return: 8991.19
# Episode 707, Total Return: 8336.05
# Episode 708, Total Return: 13584.95
# Episode 709, Total Return: 13150.40
# Episode 710, Total Return: 13841.42
# Episode 711, Total Return: -3875.83
# Episode 712, Total Return: 7128.00
# Episode 713, Total Return: -8625.50
# Episode 714, Total Return: 1312.97
# Episode 715, Total Return: -2552.51
# Episode 716, Total Return: -1729.90
# Episode 717, Total Return: 11827.82
# Episode 718, Total Return: 4158.04
# Episode 719, Total Return: 845.87
# Episode 720, Total Return: 6633.15
# Episode 721, Total Return: 6541.33
# Episode 722, Total Return: 4958.85
# Episode 723, Total Return: 14095.07
# Episode 724, Total Return: 1744.86
# Episode 725, Total Return: 18183.36
# Episode 726, Total Return: 14601.75
# Episode 727, Total Return: 5649.51
# Episode 728, Total Return: 16846.24
# Episode 729, Total Return: 4126.25
# Episode 730, Total Return: 13043.15
# Episode 731, Total Return: 4726.43
# Episode 732, Total Return: 7975.40
# Episode 733, Total Return: 9227.63
# Episode 734, Total Return: 3594.49
# Episode 735, Total Return: 11260.05
# Episode 736, Total Return: 1522.21
# Episode 737, Total Return: 3909.00
# Episode 738, Total Return: 2312.62
# Episode 739, Total Return: 14317.52
# Episode 740, Total Return: 11987.17
# Episode 741, Total Return: 16676.86
# Episode 742, Total Return: 8894.85
# Episode 743, Total Return: 876.61
# Episode 744, Total Return: 5642.02
# Episode 745, Total Return: 12409.79
# Episode 746, Total Return: -1267.34
# Episode 747, Total Return: 12727.30
# Episode 748, Total Return: 2090.42
# Episode 749, Total Return: 15490.80
# Episode 750, Total Return: 3503.20
# Episode 751, Total Return: 21002.81
# Episode 752, Total Return: -1521.95
# Episode 753, Total Return: 12260.46
# Episode 754, Total Return: 9441.85
# Episode 755, Total Return: 6030.38
# Episode 756, Total Return: 5113.76
# Episode 757, Total Return: 11273.88
# Episode 758, Total Return: 8768.02
# Episode 759, Total Return: 1380.00
# Episode 760, Total Return: 4517.52
# Episode 761, Total Return: 626.21
# Episode 762, Total Return: 9057.35
# Episode 763, Total Return: 5863.60
# Episode 764, Total Return: 7143.64
# Episode 765, Total Return: 13553.27
# Episode 766, Total Return: 14166.41
# Episode 767, Total Return: 15096.99
# Episode 768, Total Return: 10383.75
# Episode 769, Total Return: -1324.36
# Episode 770, Total Return: 2928.46
# Episode 771, Total Return: 8410.89
# Episode 772, Total Return: 188.70
# Episode 773, Total Return: 18929.14
# Episode 774, Total Return: 6877.30
# Episode 775, Total Return: 2426.06
# Episode 776, Total Return: 10825.13
# Episode 777, Total Return: 7728.14
# Episode 778, Total Return: 2050.75
# Episode 779, Total Return: -9961.21
# Episode 780, Total Return: 4197.43
# Episode 781, Total Return: 9594.05
# Episode 782, Total Return: 3427.73
# Episode 783, Total Return: 5774.27
# Episode 784, Total Return: 2719.04
# Episode 785, Total Return: 7129.64
# Episode 786, Total Return: 10886.70
# Episode 787, Total Return: 11453.14
# Episode 788, Total Return: -2825.81
# Episode 789, Total Return: -4530.71
# Episode 790, Total Return: 3787.04
# Episode 791, Total Return: 6066.55
# Episode 792, Total Return: -295.02
# Episode 793, Total Return: -6262.10
# Episode 794, Total Return: -6813.31
# Episode 795, Total Return: -4423.48
# Episode 796, Total Return: 10063.26
# Episode 797, Total Return: -795.47
# Episode 798, Total Return: 11284.15
# Episode 799, Total Return: 2620.91
# Episode 800, Total Return: 14915.76
# Episode 801, Total Return: -3014.97
# Episode 802, Total Return: 2454.32
# Episode 803, Total Return: 5086.93
# Episode 804, Total Return: 11622.68
# Episode 805, Total Return: 270.72
# Episode 806, Total Return: 6265.63
# Episode 807, Total Return: -1339.50
# Episode 808, Total Return: 8227.71
# Episode 809, Total Return: 4535.77
# Episode 810, Total Return: 6653.32
# Episode 811, Total Return: 10378.93
# Episode 812, Total Return: 1101.39
# Episode 813, Total Return: 3430.95
# Episode 814, Total Return: 1817.03
# Episode 815, Total Return: -289.84
# Episode 816, Total Return: 5209.97
# Episode 817, Total Return: 8325.72
# Episode 818, Total Return: 159.83
# Episode 819, Total Return: 5507.48
# Episode 820, Total Return: 4825.26
# Episode 821, Total Return: 6241.99
# Episode 822, Total Return: 10575.29
# Episode 823, Total Return: 8478.44
# Episode 824, Total Return: 3500.07
# Episode 825, Total Return: -1520.18
# Episode 826, Total Return: 3842.13
# Episode 827, Total Return: 9578.28
# Episode 828, Total Return: 9657.18
# Episode 829, Total Return: 13221.53
# Episode 830, Total Return: 6860.86
# Episode 831, Total Return: 9453.01
# Episode 832, Total Return: 4874.63
# Episode 833, Total Return: 7518.49
# Episode 834, Total Return: 6985.33
# Episode 835, Total Return: 3383.40
# Episode 836, Total Return: 11049.42
# Episode 837, Total Return: 11336.72
# Episode 838, Total Return: 5911.12
# Episode 839, Total Return: 9615.64
# Episode 840, Total Return: 5370.47
# Episode 841, Total Return: -1501.20
# Episode 842, Total Return: 5376.78
# Episode 843, Total Return: 8585.35
# Episode 844, Total Return: 6395.99
# Episode 845, Total Return: 3431.85
# Episode 846, Total Return: 9613.47
# Episode 847, Total Return: 857.96
# Episode 848, Total Return: 6590.34
# Episode 849, Total Return: 4134.08
# Episode 850, Total Return: 7782.58
# Episode 851, Total Return: 10711.76
# Episode 852, Total Return: 4506.50
# Episode 853, Total Return: 11579.33
# Episode 854, Total Return: 3807.95
# Episode 855, Total Return: 2085.40
# Episode 856, Total Return: 4910.89
# Episode 857, Total Return: 10129.94
# Episode 858, Total Return: 3058.81
# Episode 859, Total Return: 10313.09
# Episode 860, Total Return: 8329.13
# Episode 861, Total Return: 4027.89
# Episode 862, Total Return: 9656.70
# Episode 863, Total Return: 7862.95
# Episode 864, Total Return: 7901.55
# Episode 865, Total Return: 8376.71
# Episode 866, Total Return: -2830.08
# Episode 867, Total Return: 12263.65
# Episode 868, Total Return: 2979.51
# Episode 869, Total Return: 5992.76
# Episode 870, Total Return: -362.81
# Episode 871, Total Return: 4035.30
# Episode 872, Total Return: 4012.87
# Episode 873, Total Return: 8036.13
# Episode 874, Total Return: 9804.01
# Episode 875, Total Return: 6283.73
# Episode 876, Total Return: -724.34
# Episode 877, Total Return: 4337.95
# Episode 878, Total Return: 6995.18
# Episode 879, Total Return: 6845.39
# Episode 880, Total Return: -5601.67
# Episode 881, Total Return: 6239.91
# Episode 882, Total Return: 9562.23
# Episode 883, Total Return: 8179.65
# Episode 884, Total Return: 4782.06
# Episode 885, Total Return: 8718.25
# Episode 886, Total Return: 4876.57
# Episode 887, Total Return: 3632.73
# Episode 888, Total Return: 8838.13
# Episode 889, Total Return: -6617.92
# Episode 890, Total Return: 4553.19
# Episode 891, Total Return: 8123.44
# Episode 892, Total Return: -1139.17
# Episode 893, Total Return: 6316.83
# Episode 894, Total Return: 1551.51
# Episode 895, Total Return: 810.82
# Episode 896, Total Return: 4148.13
# Episode 897, Total Return: 9900.14
# Episode 898, Total Return: 9619.56
# Episode 899, Total Return: 9524.81
# Episode 900, Total Return: 6430.48
# Episode 901, Total Return: 5177.30
# Episode 902, Total Return: 6223.52
# Episode 903, Total Return: 8797.52
# Episode 904, Total Return: 3754.65
# Episode 905, Total Return: 4658.33
# Episode 906, Total Return: 6906.55
# Episode 907, Total Return: 2704.75
# Episode 908, Total Return: 1933.04
# Episode 909, Total Return: 8320.82
# Episode 910, Total Return: 9197.10
# Episode 911, Total Return: 5360.89
# Episode 912, Total Return: 8353.39
# Episode 913, Total Return: 5223.68
# Episode 914, Total Return: 6482.16
# Episode 915, Total Return: 12189.03
# Episode 916, Total Return: 8328.20
# Episode 917, Total Return: 7707.09
# Episode 918, Total Return: -739.73
# Episode 919, Total Return: 1751.24
# Episode 920, Total Return: 8150.12
# Episode 921, Total Return: 7108.42
# Episode 922, Total Return: 5782.35
# Episode 923, Total Return: 6921.82
# Episode 924, Total Return: 11034.49
# Episode 925, Total Return: 3977.16
# Episode 926, Total Return: 9873.62
# Episode 927, Total Return: -9419.01
# Episode 928, Total Return: 12890.53
# Episode 929, Total Return: 12932.60
# Episode 930, Total Return: 5478.08
# Episode 931, Total Return: 1087.32
# Episode 932, Total Return: 10748.67
# Episode 933, Total Return: 9966.44
# Episode 934, Total Return: 14440.12
# Episode 935, Total Return: 4535.33
# Episode 936, Total Return: 8130.65
# Episode 937, Total Return: 12769.86
# Episode 938, Total Return: 13995.98
# Episode 939, Total Return: -5279.77
# Episode 940, Total Return: 8573.17
# Episode 941, Total Return: 3024.24
# Episode 942, Total Return: 483.84
# Episode 943, Total Return: 4870.03
# Episode 944, Total Return: 8096.06
# Episode 945, Total Return: 9109.86
# Episode 946, Total Return: 6947.87
# Episode 947, Total Return: 341.30
# Episode 948, Total Return: 6417.51
# Episode 949, Total Return: 1652.61
# Episode 950, Total Return: 19211.69
# Episode 951, Total Return: 2902.16
# Episode 952, Total Return: -7123.53
# Episode 953, Total Return: 733.53
# Episode 954, Total Return: -354.43
# Episode 955, Total Return: 1806.97
# Episode 956, Total Return: 9052.52
# Episode 957, Total Return: 9505.23
# Episode 958, Total Return: 6188.07
# Episode 959, Total Return: 2903.03
# Episode 960, Total Return: 562.74
# Episode 961, Total Return: 1998.55
# Episode 962, Total Return: 11269.55
# Episode 963, Total Return: 5323.64
# Episode 964, Total Return: 3093.03
# Episode 965, Total Return: 12673.00
# Episode 966, Total Return: -2866.01
# Episode 967, Total Return: -8447.43
# Episode 968, Total Return: 10828.99
# Episode 969, Total Return: 1897.65
# Episode 970, Total Return: 1287.00
# Episode 971, Total Return: 5891.11
# Episode 972, Total Return: 8716.02
# Episode 973, Total Return: 7004.54
# Episode 974, Total Return: 2023.77
# Episode 975, Total Return: -2995.36
# Episode 976, Total Return: 7920.63
# Episode 977, Total Return: 5499.73
# Episode 978, Total Return: 8116.87
# Episode 979, Total Return: 1337.39
# Episode 980, Total Return: 1660.21
# Episode 981, Total Return: 10448.24
# Episode 982, Total Return: 10296.62
# Episode 983, Total Return: 803.30
# Episode 984, Total Return: 1594.22
# Episode 985, Total Return: 12600.14
# Episode 986, Total Return: 13397.23
# Episode 987, Total Return: 1449.35
# Episode 988, Total Return: 1196.47
# Episode 989, Total Return: 3282.63
# Episode 990, Total Return: 7545.41
# Episode 991, Total Return: 6443.02
# Episode 992, Total Return: 556.78
# Episode 993, Total Return: 9606.48
# Episode 994, Total Return: -1001.89
# Episode 995, Total Return: 9750.91
# Episode 996, Total Return: 8285.40
# Episode 997, Total Return: 8290.69
# Episode 998, Total Return: -408.55
# Episode 999, Total Return: 10374.91
# Episode 1000, Total Return: 7008.27
# Training complete.
